# %% [markdown]
# # task 1: how to disply rbg image with matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('hh.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img = cv2.imread('hh.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # task 2 : how to display an image using other liberaries(Excluding opencv and matplotlib)

# %%
from PIL import Image
img = Image.open('hh.jpg')
img.show()
  
# prints format of image
print(img.format)
  
# prints mode of image
print(img.mode)
# Out:
# JPEG
# RGB

# %% [markdown]
# # task3 : get the shape of an image

# %%
import cv2

img = cv2.imread('hh.jpg')
dimensions = img.shape
dimensions
# Out:
# (1080, 1920, 3)

# %% [markdown]
# # task 4: How to download any image or video using URL

# %%
from pytube import YouTube
import numpy as np

link = input("enter your youtube link")
myvideo = YouTube(link)
x =myvideo.streams
print("Here is the avalible resolutions please choose one: \n")
new_list = [str(i) for i in x]
for em in range(len(new_list)):
    split = new_list[em].split()
    print(split[3])
        
user = input("what res did you choose?")
myvideo.streams.filter(res=user, type='video').first().download()

print("done")
# Out:
# enter your youtube linkhttps://www.youtube.com/watch?v=-NXONiOtQYE
# Here is the avalible resolutions please choose one:
#
# res="144p"
# res="360p"
# res="360p"
# res="360p"
# res="240p"
# res="240p"
# res="144p"
# res="144p"
# abr="48kbps"
# abr="128kbps"
# abr="50kbps"
# abr="70kbps"
# abr="160kbps"
# what res did you choose?144p
# done

# %% [markdown]
# https://www.youtube.com/watch?v=-NXONiOtQYE

# %% [markdown]
# # download file or image...

# %%
import requests
url = input("your link for any thing ..file,pics..etc.")
r = requests.get(url, allow_redirects=True)
#save and name your file
ex = input("what is the name and extention of the file?")
open(ex, 'wb').write(r.content)
print("Download is done!")

# %% [markdown]
# # how to download youtube video without pytube
# ref: https://codereview.stackexchange.com/questions/162554/youtube-video-downloader

# %%
from bs4 import BeautifulSoup
import urllib.request, urllib.parse
import os
directory = os.path.abspath('.') 

url = 'https://www.youtube.com/watch?v=-NXONiOtQYE'
def get_sourcecode(url):
    return urllib.request.urlopen(url).read()

def get_info():
    return urllib.parse.parse_qs(get_sourcecode(url).decode('unicode_escape'))

def get_video_title_path():
    try:
        return os.path.join(directory, '{}.mp4'.format(get_info()['title'][0]))
    except KeyError:
        print('Parsing error, please rerun the code!')

def get_stream_map_list():
    video_links = []
    for video_stream in get_info()['url']:
        if "googlevideo" == video_stream.split('/')[2].split('.')[1]:
            video_links.append(video_stream)
    return video_links
counter = 0
for x in range(6):  #len(get_stream_map_list())
    y = get_stream_map_list()[x].split(",")
    print(f"the quality number : {counter}, : {y[14]}")
    counter =counter+1

num = int(input('enter the quality number you want: \n'))    
nee = get_stream_map_list()[num].split()[0]
  
title_path = get_video_title_path()  
get_sourcecode(url)
urllib.request.urlretrieve(nee, title_path)
# Out:
# <ipython-input-96-a9fb4dfe94d3>:11: DeprecationWarning: invalid escape sequence '\/'
#   return urllib.parse.parse_qs(get_sourcecode(url).decode('unicode_escape'))
# the quality number : 0, : "qualityLabel":"360p"
# the quality number : 1, : "qualityLabel":"360p"
# the quality number : 2, : "qualityLabel":"240p"
# the quality number : 3, : "qualityLabel":"240p"
# the quality number : 4, : "qualityLabel":"144p"
# the quality number : 5, : "qualityLabel":"144p"
# enter the quality number you want:
# 5
# Parsing error, please rerun the code!
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-96-a9fb4dfe94d3> in <module>
#      34 title_path = get_video_title_path()
#      35 get_sourcecode(url)
# ---> 36 urllib.request.urlretrieve(nee, title_path)
#
# ~\anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
# ...
