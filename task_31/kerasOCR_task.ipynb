# %%
# !pip install keras-ocr

# %%
# !wget https://i.ytimg.com/vi/7TqJQyVN-CI/maxresdefault.jpg
# Out:
# --2021-11-24 13:37:01--  https://i.ytimg.com/vi/7TqJQyVN-CI/maxresdefault.jpg
# Resolving i.ytimg.com (i.ytimg.com)... 74.125.202.119, 74.125.69.119, 64.233.183.119, ...
# Connecting to i.ytimg.com (i.ytimg.com)|74.125.202.119|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 148985 (145K) [image/jpeg]
# Saving to: ‘maxresdefault.jpg’
#
# maxresdefault.jpg   100%[===================>] 145.49K  --.-KB/s    in 0.002s
#
# 2021-11-24 13:37:01 (63.3 MB/s) - ‘maxresdefault.jpg’ saved [148985/148985]

# %%
# !wget https://c8.alamy.com/comp/P6X6KN/text-sign-showing-what-is-your-life-purpose-question-conceptual-photo-personal-determination-aims-achieve-goal-wooden-background-ideas-messages-inten-P6X6KN.jpg
# Out:
# --2021-11-24 13:38:01--  https://c8.alamy.com/comp/P6X6KN/text-sign-showing-what-is-your-life-purpose-question-conceptual-photo-personal-determination-aims-achieve-goal-wooden-background-ideas-messages-inten-P6X6KN.jpg
# Resolving c8.alamy.com (c8.alamy.com)... 52.52.242.129, 54.241.162.82
# Connecting to c8.alamy.com (c8.alamy.com)|52.52.242.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘text-sign-showing-what-is-your-life-purpose-question-conceptual-photo-personal-determination-aims-achieve-goal-wooden-background-ideas-messages-inten-P6X6KN.jpg’
#
# text-sign-showing-w     [ <=>                ] 245.99K  --.-KB/s    in 0.1s
#
# Last-modified header invalid -- time-stamp ignored.
# 2021-11-24 13:38:01 (1.66 MB/s) - ‘text-sign-showing-what-is-your-life-purpose-question-conceptual-photo-personal-determination-aims-achieve-goal-wooden-background-ideas-messages-inten-P6X6KN.jpg’ saved [251891]

# %%
import matplotlib.pyplot as plt
import keras_ocr

pipeline = keras_ocr.pipeline.Pipeline()

images = []
for img in [ 
           'text-sign-showing-what-is-your-life-purpose-question-conceptual-photo-personal-determination-aims-achieve-goal-wooden-background-ideas-messages-inten-P6X6KN.jpg',
           'maxresdefault.jpg'
            ]:
             result = keras_ocr.tools.read(img)
             images.append(result)

        
   
   
   



prediction_groups = pipeline.recognize(images)
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5

# %% [markdown]
# the next command for solving (annotate() missing 1 required positional argument: 's' ) problem if showed

# %%
# !pip install --upgrade matplotlib
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 5.4 MB/s
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...
